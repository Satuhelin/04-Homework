# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
#!pip install python-dotenv
# Out:
# ...
# You are using pip version 19.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from dotenv import load_dotenv
load_dotenv()

import os

API_KEY = os.getenv("Darksky_API_KEY")

# %%
import requests

response= requests.get(f'https://api.darksky.net/forecast/{API_KEY}/37.8267,-122.4233')
forecast=response.json()
forecast
# Out:
# {'latitude': 37.8267,
#  'longitude': -122.4233,
#  'timezone': 'America/Los_Angeles',
#  'currently': {'time': 1560193807,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'nearestStormDistance': 699,
#   'nearestStormBearing': 118,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 84.09,
#   'apparentTemperature': 84.09,
#   'dewPoint': 46.74,
#   'humidity': 0.27,
#   'pressure': 1015.95,
#   'windSpeed': 1.22,
#   'windGust': 6.97,
#   'windBearing': 63,
#   'cloudCover': 0.18,
#   'uvIndex': 8,
#   'visibility': 10,
#   'ozone': 331.14},
#  'minutely': {'summary': 'Clear for the hour.',
#   'icon': 'clear-day',
#   'data': [{'time': 1560193800, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560193860, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560193920, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560193980, 'precipIntensity': 0, 'precipProbability': 0},
# ...

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
import requests

response= requests.get(f'https://api.darksky.net/forecast/{API_KEY}/61.9852,-24.0719')
ruovesi_forecast=response.json()
ruovesi_forecast
# Out:
# {'latitude': 61.9852,
#  'longitude': -24.0719,
#  'timezone': 'Atlantic/Reykjavik',
#  'currently': {'time': 1560193929,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 51.25,
#   'apparentTemperature': 51.25,
#   'dewPoint': 43.41,
#   'humidity': 0.74,
#   'pressure': 1032.41,
#   'windSpeed': 10.35,
#   'windGust': 12.9,
#   'windBearing': 146,
#   'cloudCover': 0.15,
#   'uvIndex': 1,
#   'visibility': 10,
#   'ozone': 334.46},
#  'hourly': {'summary': 'Mostly cloudy starting later this evening.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1560193200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 51.24,
#     'apparentTemperature': 51.24,
#     'dewPoint': 43.35,
#     'humidity': 0.74,
#     'pressure': 1032.32,
#     'windSpeed': 10.34,
#     'windGust': 12.76,
#     'windBearing': 146,
# ...

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
forecast
# Out:
# {'latitude': 37.8267,
#  'longitude': -122.4233,
#  'timezone': 'America/Los_Angeles',
#  'currently': {'time': 1559961399,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'nearestStormDistance': 170,
#   'nearestStormBearing': 51,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 64.75,
#   'apparentTemperature': 64.75,
#   'dewPoint': 47.64,
#   'humidity': 0.54,
#   'pressure': 1015.29,
#   'windSpeed': 6.97,
#   'windGust': 15.49,
#   'windBearing': 275,
#   'cloudCover': 0,
#   'uvIndex': 0,
#   'visibility': 5.91,
#   'ozone': 326.82},
#  'minutely': {'summary': 'Clear for the hour.',
#   'icon': 'clear-day',
#   'data': [{'time': 1559961360, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961420, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961480, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1559961540, 'precipIntensity': 0, 'precipProbability': 0},
# ...

# %%
#documentation WindSpeed=6.97 meters per second

# %%
apparentTemperature=64.75
temperature=64.75
difference = apparentTemperature-temperature
print(difference)
# Out:
# 0.0

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %%
response=requests.get(f'https://api.darksky.net/forecast/{API_KEY}/61.9852,-24.0719?/exclude=currently,flags')
moon=response.json()
moon
# Out:
# {'latitude': 61.9852,
#  'longitude': -24.0719,
#  'timezone': 'Atlantic/Reykjavik',
#  'currently': {'time': 1560193969,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 51.25,
#   'apparentTemperature': 51.25,
#   'dewPoint': 43.41,
#   'humidity': 0.74,
#   'pressure': 1032.42,
#   'windSpeed': 10.35,
#   'windGust': 12.91,
#   'windBearing': 146,
#   'cloudCover': 0.16,
#   'uvIndex': 1,
#   'visibility': 10,
#   'ozone': 334.43},
#  'hourly': {'summary': 'Mostly cloudy starting later this evening.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1560193200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 51.24,
#     'apparentTemperature': 51.24,
#     'dewPoint': 43.35,
#     'humidity': 0.74,
#     'pressure': 1032.32,
#     'windSpeed': 10.34,
#     'windGust': 12.76,
#     'windBearing': 146,
# ...

# %%
daily = {'time': 1559952000,
    'summary': 'Clear throughout the day.',
    'icon': 'clear-day',
    'sunriseTime': 1559966059,
    'sunsetTime': 1560035956,
    'moonPhase': 0.18,
    'precipIntensity': 0.0001,
    'precipIntensityMax': 0.0002,
    'precipIntensityMaxTime': 1559962800,
    'precipProbability': 0.09,
    'precipType': 'rain',
    'temperatureHigh': 49.99,
    'temperatureHighTime': 1560020400,
    'temperatureLow': 49.06,
    'temperatureLowTime': 1560067200,
    'apparentTemperatureHigh': 45.28,
    'apparentTemperatureHighTime': 1560020400,
    'apparentTemperatureLow': 44.61,
    'apparentTemperatureLowTime': 1560031200,
    'dewPoint': 39.84,
    'humidity': 0.71,
    'pressure': 1019.29,
    'windSpeed': 15.22,
    'windGust': 20.44,
    'windGustTime': 1559970000,
    'windBearing': 350,
    'cloudCover': 0.04,
    'uvIndex': 5,
    'uvIndexTime': 1559998800,
    'visibility': 10,
    'ozone': 385.82,
    'temperatureMin': 47.68,
    'temperatureMinTime': 1559962800,
    'temperatureMax': 49.99,
    'temperatureMaxTime': 1560020400,
    'apparentTemperatureMin': 41.17,
    'apparentTemperatureMinTime': 1559962800,
    'apparentTemperatureMax': 45.29,
    'apparentTemperatureMaxTime': 1560024000}

# %%
print (daily['moonPhase'], "of Moon is showing")
# Out:
# 0.18 of Moon is showing

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %%
daily['temperatureHigh']-daily['temperatureLow']
# Out:
# 0.9299999999999997

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
import requests
response=requests.get(f'https://api.darksky.net/forecast/{API_KEY}/61.9852,-24.0719?')
daily_forecast=response.json()
every_day_forecast=daily_forecast['daily']
print(daily_forecast['daily'])
# Out:
# {'summary': 'Light rain next Monday, with high temperatures rising to 53°F on Saturday.', 'icon': 'rain', 'data': [{'time': 1560124800, 'summary': 'Partly cloudy starting in the evening.', 'icon': 'partly-cloudy-night', 'sunriseTime': 1560138722, 'sunsetTime': 1560208938, 'moonPhase': 0.26, 'precipIntensity': 0.0001, 'precipIntensityMax': 0.0002, 'precipIntensityMaxTime': 1560157200, 'precipProbability': 0.1, 'precipType': 'rain', 'temperatureHigh': 51.24, 'temperatureHighTime': 1560193200, 'temperatureLow': 49.77, 'temperatureLowTime': 1560240000, 'apparentTemperatureHigh': 51.24, 'apparentTemperatureHighTime': 1560193200, 'apparentTemperatureLow': 43.63, 'apparentTemperatureLowTime': 1560240000, 'dewPoint': 43.46, 'humidity': 0.77, 'pressure': 1029.57, 'windSpeed': 7.72, 'windGust': 16.04, 'windGustTime': 1560207600, 'windBearing': 158, 'cloudCover': 0.13, 'uvIndex': 5, 'uvIndexTime': 1560168000, 'visibility': 10, 'ozone': 346.88, 'temperatureMin': 49.4, 'temperatureMinTime': 15601
# ...

# %%
type(daily_forecast['daily']["data"])
# Out:
# list

# %%
len(daily_forecast['daily']["data"])
# Out:
# 8

# %%
print(daily_forecast['daily']["data"][0]['temperatureMax'])
# Out:
# 51.29

# %%
for dayinfo in daily_forecast['daily']['data'][1:]:
    print(dayinfo['temperatureMax'])
# Out:
# 50.81
# 50.82
# 51.23
# 52.12
# 53.05
# 52.74
# 52.75

# %%
print(daily_forecast['daily']["data"][1]['temperatureMax'])
print(daily_forecast['daily']["data"][2]['temperatureMax'])
print(daily_forecast['daily']["data"][3]['temperatureMax'])
print(daily_forecast['daily']["data"][4]['temperatureMax'])
print(daily_forecast['daily']["data"][5]['temperatureMax'])
print(daily_forecast['daily']["data"][6]['temperatureMax'])
print(daily_forecast['daily']["data"][7]['temperatureMax'])
# Out:
# 50.81
# 50.82
# 51.23
# 52.12
# 53.05
# 52.74
# 52.75

# %%
for dayinfo in daily_forecast['daily']['data'][1:]:
    if dayinfo['temperatureMax']<45:
        print("It is cold")
    elif dayinfo['temperatureMax']>50:
         print("it is hot")
    else:
        print("It is warm")
# Out:
# it is hot
# it is hot
# it is hot
# it is hot
# it is hot
# it is hot
# it is hot

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %%
import requests

response= requests.get(f'https://api.darksky.net/forecast/{API_KEY}/25.7617,-80.1918')
Miami_data=response.json()
Miami_data
# Out:
# {'latitude': 25.7617,
#  'longitude': -80.1918,
#  'timezone': 'America/New_York',
#  'currently': {'time': 1560194167,
#   'summary': 'Humid and Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'nearestStormDistance': 25,
#   'nearestStormBearing': 278,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 83.77,
#   'apparentTemperature': 89.87,
#   'dewPoint': 72.76,
#   'humidity': 0.7,
#   'pressure': 1017.41,
#   'windSpeed': 4.6,
#   'windGust': 5.59,
#   'windBearing': 149,
#   'cloudCover': 0.75,
#   'uvIndex': 6,
#   'visibility': 9.93,
#   'ozone': 291.68},
#  'minutely': {'summary': 'Humid and mostly cloudy for the hour.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1560194160, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560194220, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560194280, 'precipIntensity': 0, 'precipProbability': 0},
# ...

# %%
Miami_data['hourly']
# Out:
# {'summary': 'Rain until this evening.',
#  'icon': 'rain',
#  'data': [{'time': 1560020400,
#    'summary': 'Rain',
#    'icon': 'rain',
#    'precipIntensity': 0.138,
#    'precipProbability': 0.93,
#    'precipType': 'rain',
#    'temperature': 81.37,
#    'apparentTemperature': 86.97,
#    'dewPoint': 74.04,
#    'humidity': 0.79,
#    'pressure': 1014.33,
#    'windSpeed': 6.25,
#    'windGust': 11.65,
#    'windBearing': 206,
#    'cloudCover': 0.91,
#    'uvIndex': 5,
#    'visibility': 4.56,
#    'ozone': 283.6},
#   {'time': 1560024000,
#    'summary': 'Rain',
#    'icon': 'rain',
#    'precipIntensity': 0.1173,
#    'precipProbability': 1,
#    'precipType': 'rain',
#    'temperature': 80.23,
#    'apparentTemperature': 85.26,
#    'dewPoint': 74.78,
#    'humidity': 0.84,
#    'pressure': 1014.12,
#    'windSpeed': 8.11,
#    'windGust': 11.63,
#    'windBearing': 227,
#    'cloudCover': 1,
#    'uvIndex': 3,
#    'visibility': 0.82,
#    'ozone': 283.74},
# ...

# %%
for cloudsinfo in Miami_data['hourly']['data']:
    if cloudsinfo['cloudCover']>0.50:
        print(cloudsinfo['temperature'],("and it is cloudy"))
    else:
        print(cloudsinfo['temperature'])
# Out:
# 81.37 and it is cloudy
# 80.23 and it is cloudy
# 80.26 and it is cloudy
# 84.06 and it is cloudy
# 86.16 and it is cloudy
# 84.98 and it is cloudy
# 83.87 and it is cloudy
# 83.19 and it is cloudy
# 82.54 and it is cloudy
# 81.97
# 81.58
# 79.71
# 78.2
# 77.74
# 77.92
# 77.93
# 78.71
# 79.77
# 82.03
# 84.04
# 85.6
# 86.95
# 89.44
# 90.76
# 90.35
# 88.97 and it is cloudy
# 87.44 and it is cloudy
# 86.03 and it is cloudy
# 84.49 and it is cloudy
# 83.43 and it is cloudy
# 82.84 and it is cloudy
# 82.68 and it is cloudy
# 82.38 and it is cloudy
# 81.74 and it is cloudy
# 81.13 and it is cloudy
# 79 and it is cloudy
# 77.13 and it is cloudy
# 76.85 and it is cloudy
# 77.09 and it is cloudy
# 77.9 and it is cloudy
# 79.01 and it is cloudy
# 80.52 and it is cloudy
# 82.65 and it is cloudy
# 84.36 and it is cloudy
# 85.49 and it is cloudy
# 86.85 and it is cloudy
# 89.5 and it is cloudy
# 90.83 and it is cloudy
# 90.43 and it is cloudy

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*

# %%
import requests
response = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/40.7829,-73.9654,1356307200')
central_park = response.json()
central_park
# Out:
# {'latitude': 40.7829,
#  'longitude': -73.9654,
#  'timezone': 'America/New_York',
#  'currently': {'time': 1356307200,
#   'summary': 'Clear',
#   'icon': 'clear-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 38.32,
#   'apparentTemperature': 38.32,
#   'dewPoint': 19.26,
#   'humidity': 0.46,
#   'pressure': 1012.24,
#   'windSpeed': 1.98,
#   'windGust': 4.71,
#   'windBearing': 237,
#   'cloudCover': 0.12,
#   'uvIndex': 0,
#   'visibility': 8.32},
#  'hourly': {'summary': 'Partly cloudy until afternoon.',
#   'icon': 'partly-cloudy-night',
#   'data': [{'time': 1356238800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 36.87,
#     'apparentTemperature': 31.64,
#     'dewPoint': 21.31,
#     'humidity': 0.53,
#     'pressure': 1009.74,
#     'windSpeed': 6.57,
#     'windGust': 17.01,
#     'windBearing': 302,
#     'cloudCover': 0.68,
# ...

# %%
christmas=central_park['hourly']['data']

# %%
christmas
# Out:
# [{'time': 1356238800,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 36.87,
#   'apparentTemperature': 31.64,
#   'dewPoint': 21.31,
#   'humidity': 0.53,
#   'pressure': 1009.74,
#   'windSpeed': 6.57,
#   'windGust': 17.01,
#   'windBearing': 302,
#   'cloudCover': 0.68,
#   'uvIndex': 0,
#   'visibility': 8.48},
#  {'time': 1356242400,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 36.8,
#   'apparentTemperature': 31.95,
#   'dewPoint': 22.08,
#   'humidity': 0.55,
#   'pressure': 1010.09,
#   'windSpeed': 6,
#   'windGust': 14.91,
#   'windBearing': 296,
#   'cloudCover': 0.49,
#   'uvIndex': 0,
#   'visibility': 8.25},
#  {'time': 1356246000,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 36.94,
# ...

# %%
print("It was",christmas[0]['temperature'],"in 2012")
# Out:
# It was 36.87 in 2012

# %%
#Christmas 2007
#documentation https://api.darksky.net/forecast/c698731c8822720f1eb5ffe4f2da129f/40.7829,-73.9654,1198454400
#It was 39,95 in 2007

# %%
#Chirstmas 2005
#documentation https://api.darksky.net/forecast/c698731c8822720f1eb5ffe4f2da129f/40.7829,-73.9654,1135382400
#It was 33,35 in 2005.

# %%
#API seems to work until around 1940
